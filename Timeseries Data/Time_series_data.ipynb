# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/RUTIK675LT/DM_assignment_5/blob/main/Timeseries%20Data/Time_series_data.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# **EDA -**

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('/content/Stocks timeseries data.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2015-09-18  112.209999  114.300003  111.870003  113.449997  107.524002
# 1  2015-09-21  113.669998  115.370003  113.660004  115.209999  109.192062
# 2  2015-09-22  113.379997  114.180000  112.519997  113.400002  107.476608
# 3  2015-09-23  113.629997  114.720001  113.300003  114.320000  108.348557
# 4  2015-09-24  113.250000  115.500000  112.370003  115.000000  108.993042
#
#      Volume
# 0  74285300
# 1  50222000
# 2  50346200
# 3  35756700
# 4  50219500

# %%
# Information about the dataset
df.info()

# Summary statistics of the dataset
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       756 non-null    object
#  1   Open       756 non-null    float64
#  2   High       756 non-null    float64
#  3   Low        756 non-null    float64
#  4   Close      756 non-null    float64
#  5   Adj Close  756 non-null    float64
#  6   Volume     756 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 41.5+ KB
#              Open        High         Low       Close   Adj Close  \
# count  756.000000  756.000000  756.000000  756.000000  756.000000
# mean   140.055701  141.186852  138.993056  140.142037  137.182612
# std     34.438513   34.687762   34.215165   34.448802   35.723321
# min     90.000000   91.669998   89.470001   90.339996   86.980591
# 25%    109.697500  110.507502  108.782503  109.825001  105.464344
# ...

# %%
# Check for missing values
df.isnull().sum()

# Handle missing values (e.g., fill with mean, median, or drop them)
# df.fillna(df.mean(), inplace=True)
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plotting the distribution of numerical columns
numerical_cols = df.select_dtypes(include=['float64', 'int64']).columns
for col in numerical_cols:
    plt.figure(figsize=(10,5))
    sns.distplot(df[col])
    plt.title(f'Distribution of {col}')
    plt.show()
# Out:
# <ipython-input-5-430e8848e913>:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col])
# <ipython-input-5-430e8848e913>:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col])
# <ipython-input-5-430e8848e913>:8: UserWarning:
#
# ...

# %%
# Assuming there's a 'Date' column and a 'Close' column or similar
df['Date'] = pd.to_datetime(df['Date'])
plt.figure(figsize=(15,7))
plt.plot(df['Date'], df['Close'])
plt.title('Time Series of Stock Closing Price')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.grid(True)
plt.show()

# %%
# Plotting correlation heatmap
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-7-2271bec9c8b1>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='coolwarm')

# %%
for col in numerical_cols:
    plt.figure(figsize=(10,5))
    sns.boxplot(df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %% [markdown]
# **Clustering -**

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# Re-loading the data
df = pd.read_csv('/content/Stocks timeseries data.csv')

# Selecting the features for clustering
features = ['Open', 'High', 'Low', 'Close', 'Volume']
X = df[features]

# Scaling the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Applying K-means clustering
kmeans = KMeans(n_clusters=3, random_state=42)
df['Cluster'] = kmeans.fit_predict(X_scaled)

# Returning the count of data points in each cluster
cluster_counts = df['Cluster'].value_counts()
cluster_counts
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 0    347
# 2    218
# 1    191
# Name: Cluster, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# Re-loading the data and applying clustering
df = pd.read_csv('/content/Stocks timeseries data.csv')
features = ['Open', 'High', 'Low', 'Close', 'Volume']
X = df[features]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
kmeans = KMeans(n_clusters=3, random_state=42)
df['Cluster'] = kmeans.fit_predict(X_scaled)
df['Date'] = pd.to_datetime(df['Date'])

# Time Series Plot
plt.figure(figsize=(15, 7))
for cluster in df['Cluster'].unique():
    subset = df[df['Cluster'] == cluster]
    plt.plot(subset['Date'], subset['Close'], label=f'Cluster {cluster}')

plt.title('Time Series of Stock Closing Price by Cluster')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# **Model -**

# %%
import pandas as pd

data = pd.read_csv('/content/Stocks timeseries data.csv')

# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 483.9/483.9 kB 11.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 62.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.4/159.4 kB 26.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 kB 12.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 11.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 16.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 13.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 100.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 117.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 111.4 MB/s eta 0:00:00
# ...

# %%
pip install --upgrade scipy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 34.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.1
#     Uninstalling scipy-1.10.1:
#       Successfully uninstalled scipy-1.10.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# pycaret 3.1.0 requires scipy~=1.10.1, but you have scipy 1.11.3 which is incompatible.
# ...

# %%
from pycaret.regression import *

# Initialize the environment and create the transformation pipeline
exp_reg = setup(data=data, target='Adj Close', train_size=0.95, data_split_shuffle=False, fold_strategy="timeseries", session_id=42)
# Out:
# <style type="text/css">
# #T_8a1f9_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_8a1f9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a1f9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_8a1f9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a1f9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8a1f9_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_8a1f9_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_8a1f9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8a1f9_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_8a1f9_row1_col1" class="data row1 col1" >Adj Close</td>
#     </tr>
#     <tr>
#       <th id="T_8a1f9_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_f4cfa th {
#   text-align: left;
# }
# ...

# %%
model = create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_8ead4_row10_col0, #T_8ead4_row10_col1, #T_8ead4_row10_col2, #T_8ead4_row10_col3, #T_8ead4_row10_col4, #T_8ead4_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_8ead4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ead4_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_8ead4_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_8ead4_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_8ead4_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_8ead4_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_8ead4_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
tuned_model = tune_model(model)
# Out:
# <style type="text/css">
# #T_71bac_row10_col0, #T_71bac_row10_col1, #T_71bac_row10_col2, #T_71bac_row10_col3, #T_71bac_row10_col4, #T_71bac_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_71bac" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_71bac_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_71bac_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_71bac_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_71bac_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_71bac_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_71bac_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
final_model = finalize_model(tuned_model)
save_model(final_model, 'final_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['Open', 'High', 'Low', 'Close',
#                                               'Volume'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['Date'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('rest_encoding',
#                   TransformerWrapper(include=['Date'],
#                                      transformer=TargetEnco...ate'],
#                                                                handle_missing='return_nan'))),
#                  ('clean_column_names',
#                   TransformerWrapper(transformer=CleanColumnNames())),
#                  ('actual_estimator',
# ...
